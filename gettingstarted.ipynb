# %%
import os
from dotenv import load_dotenv
# Load environment variables from .env file
load_dotenv()
os.environ["OPENAI_API_KEY"] = os.getenv('OPENAI_API_KEY')
## Langsmith Tracking
os.environ["LANGCHAIN_API_KEY"]=os.getenv("LANGCHAIN_API_KEY")
os.environ["LANGCHAIN_TRACING_V2"]="true"
os.environ["LANGCHAIN_PROJECT"]=os.getenv("LANGCHAIN_PROJECT")

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-5-nano",
)

# %%
messages = [
    (
        "system",
        "You are a helpful assistant that tells about generative AI and programming.",
    ),
    ("human", "What is generative AI?"),
]
ai_msg = llm.invoke(messages)
ai_msg
# Out:
# AIMessage(content='Generative AI refers to AI systems that can create new data that resembles the kind of data they were trained on. Instead of just recognizing patterns or making predictions, these models produce original content such as text, images, music, or code.\n\nKey ideas:\n- How it works (high level): The model learns a statistical model of a training dataset. When prompted, it samples from that learned distribution to generate new, similar data.\n- Common types:\n  - Text: Large language models like GPT that predict the next word in a sequence.\n  - Images: Diffusion models and GANs that generate pictures from noise or from prompts.\n  - Code: Models that write code snippets based on natural-language requests.\n  - Audio/music: Models that synthesize sounds or music sequences.\n- Typical workflows:\n  - Train on a large corpus of data.\n  - Use prompts or conditions to steer the generation (e.g., "write a short sci‑fi story about space travel" or "generate an image in the style of Van Gogh").\n  - Apply sampling techniques to control creativity and coherence (temperature, top-k, nucleus sampling).\n- Popular examples you might have heard of: many chatbots, image generators (like DALL-E or Stable Diffusion), code assistants, and AI music tools.\n\nApplications:\n- Content creation (articles, artwork, music, code)\n- Chatbots and virtual assistants\n- Data augmentation for training other models\n- Design and prototyping (UI mockups, product ideas)\n- Drug discovery and scientific simulations (in some domains)\n\nLimitations and considerations:\n- Hallucinations: outputs can be plausible-sounding but inaccurate or false.\n- Biases and safety: training data can encode harmful or biased patterns.\n- Copyright and originality concerns: questions about attribution and reuse of training data.\n- Resource use: training large models can be compute- and energy-intensive.\n- Reliability: factual accuracy, consistency over long passages, etc.\n\nGetting started (practical paths):\n- Use APIs for quick experiments (OpenAI, Cohere, Anthropic, etc.) to generate text, code, or images.\n- Explore open-source options: text models (GPT-Neo, Llama), image models (Stable Diffusion, diffusion-based tools), and code models (CodeGen).\n- If you prefer hands-on: try libraries like Hugging Face Transformers (for text), Diffusers (for image generation), or run small-scale experiments locally with manageable models.\n\nIf you want, tell me your goal (e.g., “write a short story,” “generate an image from a prompt,” or “generate Python code”), and I can tailor a quick starter workflow or example.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1315, 'prompt_tokens': 30, 'total_tokens': 1345, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 768, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DG4AryqiZYftyMny7ceGa5675qtSv', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019cbe71-f306-7cf2-960e-0481968a63b5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 30, 'output_tokens': 1315, 'total_tokens': 1345, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 768}})

# %%
ai_msg.text
# Out:
# 'Generative AI refers to AI systems that can create new data that resembles the kind of data they were trained on. Instead of just recognizing patterns or making predictions, these models produce original content such as text, images, music, or code.\n\nKey ideas:\n- How it works (high level): The model learns a statistical model of a training dataset. When prompted, it samples from that learned distribution to generate new, similar data.\n- Common types:\n  - Text: Large language models like GPT that predict the next word in a sequence.\n  - Images: Diffusion models and GANs that generate pictures from noise or from prompts.\n  - Code: Models that write code snippets based on natural-language requests.\n  - Audio/music: Models that synthesize sounds or music sequences.\n- Typical workflows:\n  - Train on a large corpus of data.\n  - Use prompts or conditions to steer the generation (e.g., "write a short sci‑fi story about space travel" or "generate an image in the style of Van Gogh").\n  - Apply sampling techniques to control creativity and coherence (temperature, top-k, nucleus sampling).\n- Popular examples you might have heard of: many chatbots, image generators (like DALL-E or Stable Diffusion), code assistants, and AI music tools.\n\nApplications:\n- Content creation (articles, artwork, music, code)\n- Chatbots and virtual assistants\n- Data augmentation for training other models\n- Design and prototyping (UI mockups, product ideas)\n- Drug discovery and scientific simulations (in some domains)\n\nLimitations and considerations:\n- Hallucinations: outputs can be plausible-sounding but inaccurate or false.\n- Biases and safety: training data can encode harmful or biased patterns.\n- Copyright and originality concerns: questions about attribution and reuse of training data.\n- Resource use: training large models can be compute- and energy-intensive.\n- Reliability: factual accuracy, consistency over long passages, etc.\n\nGetting started (practical paths):\n- Use APIs for quick experiments (OpenAI, Cohere, Anthropic, etc.) to generate text, code, or images.\n- Explore open-source options: text models (GPT-Neo, Llama), image models (Stable Diffusion, diffusion-based tools), and code models (CodeGen).\n- If you prefer hands-on: try libraries like Hugging Face Transformers (for text), Diffusers (for image generation), or run small-scale experiments locally with manageable models.\n\nIf you want, tell me your goal (e.g., “write a short story,” “generate an image from a prompt,” or “generate Python code”), and I can tailor a quick starter workflow or example.'

# %%
from langchain_core.output_parsers import StrOutputParser
output_parser=StrOutputParser()
output_parser.invoke(ai_msg)
# Out:
# 'Generative AI refers to AI systems that can create new data that resembles the kind of data they were trained on. Instead of just recognizing patterns or making predictions, these models produce original content such as text, images, music, or code.\n\nKey ideas:\n- How it works (high level): The model learns a statistical model of a training dataset. When prompted, it samples from that learned distribution to generate new, similar data.\n- Common types:\n  - Text: Large language models like GPT that predict the next word in a sequence.\n  - Images: Diffusion models and GANs that generate pictures from noise or from prompts.\n  - Code: Models that write code snippets based on natural-language requests.\n  - Audio/music: Models that synthesize sounds or music sequences.\n- Typical workflows:\n  - Train on a large corpus of data.\n  - Use prompts or conditions to steer the generation (e.g., "write a short sci‑fi story about space travel" or "generate an image in the style of Van Gogh").\n  - Apply sampling techniques to control creativity and coherence (temperature, top-k, nucleus sampling).\n- Popular examples you might have heard of: many chatbots, image generators (like DALL-E or Stable Diffusion), code assistants, and AI music tools.\n\nApplications:\n- Content creation (articles, artwork, music, code)\n- Chatbots and virtual assistants\n- Data augmentation for training other models\n- Design and prototyping (UI mockups, product ideas)\n- Drug discovery and scientific simulations (in some domains)\n\nLimitations and considerations:\n- Hallucinations: outputs can be plausible-sounding but inaccurate or false.\n- Biases and safety: training data can encode harmful or biased patterns.\n- Copyright and originality concerns: questions about attribution and reuse of training data.\n- Resource use: training large models can be compute- and energy-intensive.\n- Reliability: factual accuracy, consistency over long passages, etc.\n\nGetting started (practical paths):\n- Use APIs for quick experiments (OpenAI, Cohere, Anthropic, etc.) to generate text, code, or images.\n- Explore open-source options: text models (GPT-Neo, Llama), image models (Stable Diffusion, diffusion-based tools), and code models (CodeGen).\n- If you prefer hands-on: try libraries like Hugging Face Transformers (for text), Diffusers (for image generation), or run small-scale experiments locally with manageable models.\n\nIf you want, tell me your goal (e.g., “write a short story,” “generate an image from a prompt,” or “generate Python code”), and I can tailor a quick starter workflow or example.'
